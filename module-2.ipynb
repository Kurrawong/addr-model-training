# %% [markdown]
# ![](module-1/img/KurrawongAI_350.png)
#
# # Address Model Training - Module 2, Implementations
#
# ## Outline
#
# 1. QLD
#     1. Implementation Selection
#     2. Design
#         1. Non-mode elements
#         2. Model feedback
#     3. Testing
#     4. Vocabulary hosting
#     5. QALI application
#
# QALI application demo
#
# 2. ACT Implementation Proposals
# 3. Future options
